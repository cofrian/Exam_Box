# %% [markdown]
# # Pregunta 3: Machine Learning Basico
#
# **Tareas:**
# 1. Cargar el dataset iris de sklearn
# 2. Dividir en train/test
# 3. Entrenar un modelo de clasificacion
# 4. Evaluar el modelo

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
# 3.1 Cargar el dataset iris
# Tu codigo aqui

# %%
# 3.2 Dividir en train/test (80/20)
# Tu codigo aqui

# %%
# 3.3 Entrenar DecisionTreeClassifier
# Tu codigo aqui

# %%
# 3.4 Evaluar el modelo
# Tu codigo aqui
