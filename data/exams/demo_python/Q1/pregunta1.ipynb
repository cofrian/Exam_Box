# %% [markdown]
# # Pregunta 1: Analisis de Datos de Ventas
#
# En esta pregunta trabajaras con un archivo CSV que contiene datos de ventas.
#
# **Tareas:**
# 1. Cargar el archivo ventas.csv
# 2. Calcular estadisticas basicas (media, mediana, desviacion estandar)
# 3. Crear una visualizacion de los datos

# %%
# Importa las librerias necesarias
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 1.1 Carga los datos del archivo ventas.csv
# Tu codigo aqui

# %%
# 1.2 Calcula las estadisticas basicas
# Tu codigo aqui

# %%
# 1.3 Crea una visualizacion
# Tu codigo aqui
