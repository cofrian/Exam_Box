# %% [markdown]
# # Pregunta 2: Funciones y Estructuras de Datos
#
# **Tareas:**
# 1. Implementa una funcion que calcule el factorial
# 2. Crea una funcion que encuentre numeros primos
# 3. Implementa una clase Calculadora

# %%
# 2.1 Funcion factorial
def factorial(n):
    # Tu codigo aqui
    pass

# Prueba
print(factorial(5))  # Debe imprimir 120

# %%
# 2.2 Funcion para encontrar numeros primos
def primos_en_rango(inicio, fin):
    # Tu codigo aqui
    pass

# Prueba
print(primos_en_rango(1, 20))

# %%
# 2.3 Clase Calculadora
class Calculadora:
    def sumar(self, a, b):
        pass
    def restar(self, a, b):
        pass
    def multiplicar(self, a, b):
        pass
    def dividir(self, a, b):
        pass

# Prueba
calc = Calculadora()
print(calc.sumar(5, 3))
